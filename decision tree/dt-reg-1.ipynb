# %%
import pandas as pd
import seaborn as sns
import numpy as np
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import fetch_california_housing
data=fetch_california_housing()

# %%
df=pd.DataFrame(data.data,columns=data.feature_names)

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
df['Price']=data.target

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# 0        -122.23  4.526
# 1        -122.22  3.585
# 2        -122.24  3.521
# 3        -122.25  3.413
# 4        -122.25  3.422
# ...          ...    ...
# 20635    -121.09  0.781
# 20636    -121.21  0.771
# 20637    -121.22  0.923
# 20638    -121.32  0.847
# 20639    -121.24  0.894
#
# [20640 rows x 9 columns]

# %%
df.shape
# Out:
# (20640, 9)

# %%
df.sample(4)
# Out:
#         MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 10759  10.8289       9.0  6.825028   1.111849      1912.0  2.117386     33.63
# 9467    3.5000      49.0  4.780793   1.006263      1201.0  2.507307     39.44
# 20466   5.5983      24.0  7.266816   1.033632      1567.0  3.513453     34.27
# 7022    3.1607      37.0  4.523985   0.940959      1068.0  3.940959     33.98
#
#        Longitude    Price
# 10759    -117.87  5.00001
# 9467     -123.79  1.13300
# 20466    -118.75  2.33300
# 7022     -118.09  1.72200

# %%
ds=df.sample(frac=0.2)

# %%
df.shape
# Out:
# (20640, 9)

# %%
ds.shape
# Out:
# (4128, 9)

# %%
x=ds.iloc[:,:-1]
y=ds.iloc[:,-1]

# %%
x
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 12505  2.8542      52.0  5.457831   0.993976       257.0  1.548193     38.56
# 2553   2.5536      37.0  4.687097   0.945161       867.0  2.796774     40.78
# 14395  2.6625      36.0  3.887147   0.971787       577.0  1.808777     32.74
# 8716   3.5414      22.0  3.728847   1.044861      7180.0  2.038614     33.84
# 18852  2.4526      29.0  5.782051   1.121083      1700.0  2.421652     41.31
# ...       ...       ...       ...        ...         ...       ...       ...
# 8143   4.9180      36.0  6.169492   1.061017       899.0  3.047458     33.83
# 14321  1.3125      52.0  2.337209   1.063953       557.0  3.238372     32.71
# 12475  2.0100      52.0  4.535433   1.149606       273.0  2.149606     38.58
# 1376   4.1189      42.0  5.839895   0.963255       864.0  2.267717     38.01
# 10406  5.1589       3.0  4.202091   0.891986       563.0  1.961672     33.66
#
#        Longitude
# 12505    -121.44
# 2553     -124.18
# 14395    -117.25
# 8716     -118.35
# 18852    -122.30
# ...          ...
# 8143     -118.11
# 14321    -117.15
# 12475    -121.48
# 1376     -122.12
# 10406    -117.59
#
# [4128 rows x 8 columns]

# %%
y
# Out:
# 12505    1.394
# 2553     0.702
# 14395    2.482
# 8716     3.547
# 18852    0.971
#          ...
# 8143     2.252
# 14321    0.875
# 12475    0.943
# 1376     1.724
# 10406    1.678
# Name: Price, Length: 4128, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.4661698158322054

# %%
# hyperparamter tuning
parameter={
    'criterion':['squared_error','absolute_error','friedman_mse'],
    'splitter':['best','random'],
    'max_depth':[1,2,3,4,10],
    'max_features':['sqrt','log2','auto']
}

# %%
from sklearn.model_selection import GridSearchCV
mdl=GridSearchCV(model,param_grid=parameter,cv=5,scoring='neg_mean_squared_error',verbose=3)

# %%
mdl.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# [CV 1/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=best;, score=-1.402 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=best;, score=-1.329 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=best;, score=-1.312 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=best;, score=-1.199 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=best;, score=-1.172 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=random;, score=-1.528 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=random;, score=-1.315 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=random;, score=-1.023 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=random;, score=-1.245 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=random;, score=-0.958 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=best;, score=-1.398 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=best;, score=-0.900 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=best;, score=-1.141 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=best;, score=-1.110 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=best;, score=-1.198 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=random;, score=-1.558 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=random;, score=-1.100 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=random;, score=-1.296 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=random;, score=-1.234 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=random;, score=-1.252 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=best;, score=-1.216 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=best;, score=-0.761 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=best;, score=-0.875 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=best;, score=-1.097 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=best;, score=-1.055 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=random;, score=-1.551 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=random;, score=-1.279 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=random;, score=-1.234 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=random;, score=-1.195 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=random;, score=-1.263 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=best;, score=-1.245 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=best;, score=-1.248 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=best;, score=-1.055 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=best;, score=-0.739 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=best;, score=-0.962 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=random;, score=-1.256 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=random;, score=-1.286 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=random;, score=-1.281 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=random;, score=-1.058 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=random;, score=-1.267 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=best;, score=-1.126 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=best;, score=-1.058 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=best;, score=-0.702 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=best;, score=-0.789 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=best;, score=-0.834 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=random;, score=-1.180 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=random;, score=-0.863 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=random;, score=-1.322 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=random;, score=-1.122 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=random;, score=-1.178 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=best;, score=-1.243 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=best;, score=-1.034 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=best;, score=-0.712 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=best;, score=-0.706 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=best;, score=-0.677 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=random;, score=-1.161 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=random;, score=-1.011 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=random;, score=-1.284 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=random;, score=-1.170 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=random;, score=-0.864 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.766 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=best;, score=-1.037 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.687 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.748 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.952 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=random;, score=-1.436 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=random;, score=-0.908 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=random;, score=-1.176 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=random;, score=-1.076 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=random;, score=-0.985 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=best;, score=-0.723 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=best;, score=-0.633 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=best;, score=-0.608 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=best;, score=-0.687 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=best;, score=-0.611 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=random;, score=-1.438 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=random;, score=-1.219 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=random;, score=-1.022 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=random;, score=-1.191 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=random;, score=-1.228 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.731 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.702 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.696 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.578 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.777 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.933 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.793 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.616 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.732 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.857 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=best;, score=-0.577 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=best;, score=-0.668 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=best;, score=-0.672 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=best;, score=-0.569 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=best;, score=-0.684 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=random;, score=-1.018 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=random;, score=-0.682 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=random;, score=-0.536 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=random;, score=-0.672 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=random;, score=-0.624 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=best;, score=-1.025 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=best;, score=-1.423 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=best;, score=-0.955 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=best;, score=-1.215 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=best;, score=-1.257 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=random;, score=-1.592 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=random;, score=-1.470 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=random;, score=-1.422 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=random;, score=-1.298 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=random;, score=-1.294 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=best;, score=-1.405 total time=   0.1s
# [CV 2/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=best;, score=-1.345 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=best;, score=-1.315 total time=   0.1s
# [CV 4/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=best;, score=-1.215 total time=   0.1s
# [CV 5/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=best;, score=-1.248 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=random;, score=-1.607 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=random;, score=-1.431 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=random;, score=-1.352 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=random;, score=-1.301 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=random;, score=-1.282 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=best;, score=-1.238 total time=   0.1s
# [CV 2/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=best;, score=-0.801 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=best;, score=-0.997 total time=   0.1s
# [CV 4/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=best;, score=-0.929 total time=   0.1s
# [CV 5/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=best;, score=-0.813 total time=   0.1s
# [CV 1/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=random;, score=-1.119 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=random;, score=-1.385 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=random;, score=-1.422 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=random;, score=-1.288 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=random;, score=-1.344 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=best;, score=-1.008 total time=   0.1s
# [CV 2/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=best;, score=-1.129 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=best;, score=-0.772 total time=   0.1s
# [CV 4/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=best;, score=-0.867 total time=   0.1s
# [CV 5/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=best;, score=-0.911 total time=   0.1s
# [CV 1/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=random;, score=-1.599 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=random;, score=-1.424 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=random;, score=-1.394 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=random;, score=-1.305 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=random;, score=-1.284 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=best;, score=-1.147 total time=   0.1s
# [CV 2/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=best;, score=-1.007 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=best;, score=-1.131 total time=   0.1s
# [CV 4/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=best;, score=-0.950 total time=   0.1s
# [CV 5/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=best;, score=-0.991 total time=   0.1s
# [CV 1/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=random;, score=-1.134 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=random;, score=-1.486 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=random;, score=-1.393 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=random;, score=-0.903 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=random;, score=-1.116 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=best;, score=-1.089 total time=   0.1s
# [CV 2/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=best;, score=-0.843 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=best;, score=-0.955 total time=   0.1s
# [CV 4/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=best;, score=-0.775 total time=   0.1s
# [CV 5/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=best;, score=-0.791 total time=   0.1s
# [CV 1/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=random;, score=-1.452 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=random;, score=-1.296 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=random;, score=-1.105 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=random;, score=-1.281 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=random;, score=-1.030 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.746 total time=   0.1s
# [CV 2/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.866 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.678 total time=   0.1s
# [CV 4/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.841 total time=   0.1s
# [CV 5/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.886 total time=   0.1s
# [CV 1/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=random;, score=-1.309 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=random;, score=-1.126 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=random;, score=-1.358 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=random;, score=-0.837 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=random;, score=-1.322 total time=   0.1s
# [CV 1/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=best;, score=-0.747 total time=   0.1s
# [CV 2/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=best;, score=-0.647 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=best;, score=-0.773 total time=   0.1s
# [CV 4/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=best;, score=-0.620 total time=   0.1s
# [CV 5/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=best;, score=-0.659 total time=   0.1s
# [CV 1/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=random;, score=-1.177 total time=   0.1s
# [CV 2/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=random;, score=-0.890 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=random;, score=-1.091 total time=   0.1s
# [CV 4/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=random;, score=-1.122 total time=   0.1s
# [CV 5/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=random;, score=-0.727 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.765 total time=   0.1s
# [CV 2/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.645 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.602 total time=   0.1s
# [CV 4/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.692 total time=   0.1s
# [CV 5/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.786 total time=   0.2s
# [CV 1/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.968 total time=   0.1s
# [CV 2/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=random;, score=-1.100 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.935 total time=   0.1s
# [CV 4/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.864 total time=   0.1s
# [CV 5/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.861 total time=   0.1s
# [CV 1/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=best;, score=-0.740 total time=   0.1s
# [CV 2/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=best;, score=-0.578 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=best;, score=-0.554 total time=   0.1s
# [CV 4/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=best;, score=-0.544 total time=   0.2s
# [CV 5/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=best;, score=-0.648 total time=   0.2s
# [CV 1/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=random;, score=-0.872 total time=   0.1s
# [CV 2/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=random;, score=-0.672 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=random;, score=-0.658 total time=   0.1s
# [CV 4/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=random;, score=-0.735 total time=   0.1s
# [CV 5/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=random;, score=-0.628 total time=   0.1s
# [CV 1/5] END criterion=absolute_error, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=best;, score=-1.019 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=best;, score=-0.900 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=best;, score=-1.141 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=best;, score=-1.110 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=best;, score=-1.198 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=random;, score=-1.558 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=random;, score=-1.369 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=random;, score=-1.271 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=random;, score=-1.244 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=random;, score=-1.256 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=best;, score=-1.553 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=best;, score=-1.220 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=best;, score=-1.141 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=best;, score=-1.181 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=best;, score=-1.086 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=random;, score=-1.298 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=random;, score=-1.369 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=random;, score=-1.323 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=random;, score=-1.241 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=random;, score=-1.199 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=best;, score=-1.338 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=best;, score=-1.154 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=best;, score=-0.810 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=best;, score=-0.963 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=best;, score=-1.175 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=random;, score=-1.494 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=random;, score=-0.887 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=random;, score=-0.923 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=random;, score=-1.167 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=random;, score=-1.268 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=best;, score=-0.847 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=best;, score=-0.876 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=best;, score=-1.011 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=best;, score=-0.809 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=best;, score=-1.092 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=random;, score=-1.402 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=random;, score=-0.917 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=random;, score=-0.926 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=random;, score=-1.002 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=random;, score=-0.891 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=best;, score=-0.858 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=best;, score=-1.101 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=best;, score=-0.671 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=best;, score=-0.731 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=best;, score=-0.933 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=random;, score=-1.045 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=random;, score=-1.182 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=random;, score=-1.215 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=random;, score=-1.213 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=random;, score=-1.011 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=best;, score=-0.816 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=best;, score=-0.658 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=best;, score=-0.735 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=best;, score=-0.680 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=best;, score=-0.665 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=random;, score=-1.211 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=random;, score=-1.245 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=random;, score=-0.877 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=random;, score=-0.846 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=random;, score=-1.202 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=best;, score=-0.973 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=best;, score=-0.987 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=best;, score=-0.959 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=best;, score=-0.764 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=best;, score=-0.895 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=random;, score=-1.448 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=random;, score=-1.353 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=random;, score=-1.311 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=random;, score=-1.216 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=random;, score=-0.926 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=best;, score=-0.937 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=best;, score=-0.847 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=best;, score=-0.676 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=best;, score=-0.645 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=best;, score=-0.695 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=random;, score=-1.319 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=random;, score=-1.166 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=random;, score=-0.830 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=random;, score=-1.135 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=random;, score=-1.260 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=best;, score=-0.633 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=best;, score=-0.613 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=best;, score=-0.582 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=best;, score=-0.631 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=best;, score=-0.697 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=random;, score=-0.831 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=random;, score=-0.696 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=random;, score=-0.839 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=random;, score=-0.784 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=random;, score=-0.695 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=best;, score=-0.654 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=best;, score=-0.600 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=best;, score=-0.576 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=best;, score=-0.637 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=best;, score=-0.642 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=random;, score=-0.927 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=random;, score=-0.684 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=random;, score=-0.630 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=random;, score=-0.616 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=random;, score=-0.663 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_depth': [1, 2, 3, 4, 10],
#                          'max_features': ['sqrt', 'log2', 'auto'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
mdl.best_params_
# Out:
# {'criterion': 'absolute_error',
#  'max_depth': 10,
#  'max_features': 'log2',
#  'splitter': 'best'}

# %%
final_model=DecisionTreeRegressor(criterion='absolute_error',max_depth=10,max_features='log2',splitter='best')

# %%
final_model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='absolute_error', max_depth=10,
#                       max_features='log2')

# %%
from sklearn import tree
plt.figure(figsize=(12,10))
tree.plot_tree(final_model,filled=True)
plt.plot()
# Out:
# []

# %%
y_pred=final_model
