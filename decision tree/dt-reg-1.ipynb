# %%
import pandas as pd
import seaborn as sns
import numpy as np
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import fetch_california_housing
data=fetch_california_housing()

# %%
df=pd.DataFrame(data.data,columns=data.feature_names)

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
df['Price']=data.target

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# 0        -122.23  4.526
# 1        -122.22  3.585
# 2        -122.24  3.521
# 3        -122.25  3.413
# 4        -122.25  3.422
# ...          ...    ...
# 20635    -121.09  0.781
# 20636    -121.21  0.771
# 20637    -121.22  0.923
# 20638    -121.32  0.847
# 20639    -121.24  0.894
#
# [20640 rows x 9 columns]

# %%
df.shape
# Out:
# (20640, 9)

# %%
df.sample(4)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 13665  5.2139      18.0  5.733333   0.961404       899.0  3.154386     34.02
# 18507  6.4469      29.0  5.536585   1.097561       112.0  2.731707     36.99
# 13331  3.6467      14.0  5.174168   1.027397      2021.0  3.954990     34.05
# 15420  3.0197      26.0  4.463700   0.955504      1325.0  3.103044     33.21
#
#        Longitude  Price
# 13665    -117.31  1.293
# 18507    -122.01  2.714
# 13331    -117.66  1.475
# 15420    -117.26  1.360

# %%
ds=df.sample(frac=0.2)

# %%
df.shape
# Out:
# (20640, 9)

# %%
ds.shape
# Out:
# (4128, 9)

# %%
x=ds.iloc[:,:-1]
y=ds.iloc[:,-1]

# %%
x
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 5099   2.7917      47.0  5.436842   1.110526      1156.0  3.042105     33.97
# 13899  1.0568      16.0  7.842767   1.981132       433.0  2.723270     34.52
# 551    4.2260      52.0  5.011765   1.091176       663.0  1.950000     37.77
# 19442  1.1250      26.0  5.000000   1.000000        47.0  2.611111     37.67
# 17928  3.6682      33.0  4.609329   1.052478      1553.0  2.263848     37.34
# ...       ...       ...       ...        ...         ...       ...       ...
# 16677  1.9653      41.0  5.258383   1.481262       940.0  1.854043     35.13
# 9318   6.4271      34.0  7.218391   1.022989       460.0  2.643678     37.98
# 10800  6.5928      28.0  5.057307   1.117479       832.0  2.383954     33.62
# 9815   3.1359      27.0  4.925566   1.069579      1229.0  1.988673     36.61
# 1306   4.9167      23.0  6.609195   1.000000       572.0  3.287356     37.99
#
#        Longitude
# 5099     -118.31
# 13899    -116.73
# 551      -122.26
# 19442    -121.00
# 17928    -121.97
# ...          ...
# 16677    -120.66
# 9318     -122.49
# 10800    -117.94
# 9815     -121.92
# 1306     -121.83
#
# [4128 rows x 8 columns]

# %%
y
# Out:
# 5099     1.258
# 13899    0.750
# 551      2.750
# 19442    0.875
# 17928    2.661
#          ...
# 16677    2.361
# 9318     4.517
# 10800    4.391
# 9815     2.680
# 1306     1.524
# Name: Price, Length: 4128, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.5331967179417407

# %%
# hyperparamter tuning
parameter={
    'criterion':['squared_error','absolute_error','friedman_mse'],
    'splitter':['best','random'],
    'max_depth':[1,2,3,4,10],
    'max_features':['sqrt','log2','auto']
}

# %%
from sklearn.model_selection import GridSearchCV
mdl=GridSearchCV(model,param_grid=parameter,cv=5,scoring='neg_mean_squared_error',verbose=3)

# %%
mdl.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# [CV 1/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=best;, score=-1.401 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=best;, score=-1.341 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=best;, score=-0.992 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=best;, score=-1.127 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=best;, score=-0.952 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=random;, score=-1.191 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=random;, score=-1.337 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=random;, score=-1.381 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=random;, score=-1.367 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=random;, score=-1.332 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=best;, score=-0.873 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=best;, score=-0.939 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=best;, score=-1.360 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=best;, score=-1.127 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=best;, score=-0.952 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=random;, score=-1.330 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=random;, score=-1.336 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=random;, score=-1.381 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=random;, score=-1.349 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=random;, score=-1.381 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=best;, score=-0.967 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=best;, score=-1.150 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=best;, score=-1.171 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=best;, score=-0.885 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=best;, score=-1.161 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=random;, score=-1.317 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=random;, score=-1.289 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=random;, score=-1.381 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=random;, score=-1.151 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=random;, score=-1.386 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=best;, score=-0.761 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=best;, score=-0.770 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=best;, score=-0.989 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=best;, score=-1.131 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=best;, score=-0.922 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=random;, score=-0.766 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=random;, score=-1.251 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=random;, score=-1.054 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=random;, score=-1.231 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=random;, score=-1.051 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=best;, score=-1.022 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=best;, score=-1.231 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=best;, score=-0.940 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=best;, score=-0.823 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=best;, score=-0.859 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=random;, score=-1.118 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=random;, score=-1.315 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=random;, score=-1.300 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=random;, score=-1.074 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=random;, score=-1.328 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=best;, score=-0.805 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=best;, score=-0.873 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=best;, score=-0.777 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=best;, score=-0.911 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=best;, score=-0.840 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=random;, score=-1.260 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=random;, score=-0.887 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=random;, score=-1.314 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=random;, score=-1.124 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=random;, score=-1.082 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.681 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.950 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.915 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.790 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.699 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=random;, score=-0.860 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=random;, score=-1.256 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=random;, score=-1.375 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=random;, score=-1.292 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=random;, score=-0.991 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=best;, score=-0.611 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=best;, score=-0.847 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=best;, score=-0.786 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=best;, score=-0.651 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=best;, score=-0.677 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=random;, score=-1.321 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=random;, score=-1.175 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=random;, score=-1.037 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=random;, score=-1.157 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=random;, score=-1.093 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.641 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.523 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.724 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.558 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.660 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.840 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.740 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.954 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.993 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.897 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=best;, score=-0.634 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=best;, score=-0.536 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=best;, score=-0.630 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=best;, score=-0.502 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=best;, score=-0.627 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=random;, score=-0.583 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=random;, score=-0.905 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=random;, score=-0.803 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=random;, score=-0.674 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=random;, score=-0.630 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=best;, score=-1.412 total time=   0.1s
# [CV 2/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=best;, score=-1.421 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=best;, score=-1.403 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=best;, score=-1.345 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=best;, score=-0.972 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=random;, score=-1.496 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter
total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=random;, score=-1.230 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=best;, score=-0.773 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=best;, score=-0.784 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=best;, score=-0.905 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=best;, score=-0.796 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=best;, score=-1.020 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=random;, score=-1.170 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=random;, score=-1.329 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=random;, score=-1.246 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=random;, score=-1.325 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=random;, score=-1.351 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=best;, score=-1.155 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=best;, score=-0.947 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=best;, score=-1.249 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=best;, score=-0.997 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=best;, score=-0.761 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=random;, score=-1.401 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=random;, score=-1.094 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=random;, score=-1.369 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=random;, score=-1.287 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=random;, score=-1.331 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=best;, score=-0.874 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=best;, score=-0.810 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=best;, score=-0.891 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=best;, score=-0.738 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=best;, score=-0.764 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=random;, score=-1.013 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=random;, score=-1.212 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=random;, score=-1.333 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=random;, score=-1.342 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=random;, score=-1.140 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=best;, score=-0.836 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=best;, score=-0.862 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=best;, score=-0.775 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=best;, score=-0.767 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=best;, score=-1.084 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=random;, score=-0.774 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=random;, score=-1.286 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=random;, score=-1.275 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=random;, score=-1.300 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=random;, score=-1.019 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=best;, score=-0.552 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=best;, score=-0.649 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=best;, score=-0.800 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=best;, score=-0.683 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=best;, score=-0.821 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=random;, score=-0.733 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=random;, score=-1.166 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=random;, score=-1.208 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=random;, score=-1.165 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=random;, score=-0.993 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=best;, score=-0.666 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=best;, score=-0.735 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=best;, score=-0.634 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=best;, score=-0.610 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=best;, score=-0.597 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=random;, score=-0.983 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=random;, score=-0.823 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=random;, score=-1.089 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=random;, score=-0.853 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=sqrt, splitter=random;, score=-0.744 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=best;, score=-0.644 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=best;, score=-0.601 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=best;, score=-0.578 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=best;, score=-0.601 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=best;, score=-0.571 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=random;, score=-0.580 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=random;, score=-0.821 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=random;, score=-0.747 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=random;, score=-0.631 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=log2, splitter=random;, score=-0.721 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=auto, splitter=random;, score=nan total time=   0.0s
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_depth': [1, 2, 3, 4, 10],
#                          'max_features': ['sqrt', 'log2', 'auto'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
mdl.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 10,
#  'max_features': 'log2',
#  'splitter': 'best'}

# %%
final_model=DecisionTreeRegressor(criterion='absolute_error',max_depth=10,max_features='log2',splitter='best')

# %%
final_model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='absolute_error', max_depth=10,
#                       max_features='log2')

# %%
from sklearn import tree
plt.figure(figsize=(12,10))
tree.plot_tree(final_model,filled=True)
plt.plot()
# Out:
# []

# %%
y_pred=final_model.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6501197905682987
