# %%
import pandas as pd
import seaborn as sns
import numpy as np
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import fetch_california_housing

# %%
ds=fetch_california_housing()

# %%
ds
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]], shape=(20640, 8)),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894], shape=(20640,)),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
# ...

# %%
print(ds.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# ...

# %%
ds.target_names
# Out:
# ['MedHouseVal']

# %%
ds.feature_names
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %%
df=pd.DataFrame(ds.data,columns=ds.feature_names)

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
df['price']=ds.target

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  price
# ...

# %%
df.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
xx=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
xx
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
x
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
x
x.drop(['AveBedrms', 'Latitude','Longitude'], axis=1, inplace=True)

# %%
x
# Out:
#        MedInc  HouseAge  AveRooms  Population  AveOccup
# 0      8.3252      41.0  6.984127       322.0  2.555556
# 1      8.3014      21.0  6.238137      2401.0  2.109842
# 2      7.2574      52.0  8.288136       496.0  2.802260
# 3      5.6431      52.0  5.817352       558.0  2.547945
# 4      3.8462      52.0  6.281853       565.0  2.181467
# ...       ...       ...       ...         ...       ...
# 20635  1.5603      25.0  5.045455       845.0  2.560606
# 20636  2.5568      18.0  6.114035       356.0  3.122807
# 20637  1.7000      17.0  5.205543      1007.0  2.325635
# 20638  1.8672      18.0  5.329513       741.0  2.123209
# 20639  2.3886      16.0  5.254717      1387.0  2.616981
#
# [20640 rows x 5 columns]

# %%
y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: price, Length: 20640, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(xx,y,test_size=0.2,random_state=1)

# %%
x_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 15961  3.1908      52.0  5.000000   1.014184       879.0  3.117021     37.71
# 1771   3.6094      42.0  4.900990   0.957096       971.0  3.204620     37.95
# 16414  2.6250      16.0  8.333333   1.666667        20.0  3.333333     37.90
# 5056   1.5143      34.0  3.805981   1.149526      3538.0  2.580598     34.02
# 8589   7.3356      38.0  5.894904   1.057325       750.0  2.388535     33.89
# ...       ...       ...       ...        ...         ...       ...       ...
# 10955  1.7823      17.0  4.055046   1.087156      1079.0  2.474771     33.76
# 17289  8.5608      42.0  6.788462   1.011538       753.0  2.896154     34.42
# 5192   1.1326      42.0  4.890785   1.006826       775.0  2.645051     33.93
# 12172  2.6322      10.0  4.991614   0.951782      1323.0  2.773585     33.73
# 235    2.3036      35.0  4.620513   1.176923      1009.0  2.587179     37.79
#
#        Longitude
# 15961    -122.43
# ...

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 0.5291402345397312

# %%
xx.drop(['AveBedrms', 'Latitude','Longitude'], axis=1, inplace=True)

# %%
xx
# Out:
#        MedInc  HouseAge  AveRooms  Population  AveOccup
# 0      8.3252      41.0  6.984127       322.0  2.555556
# 1      8.3014      21.0  6.238137      2401.0  2.109842
# 2      7.2574      52.0  8.288136       496.0  2.802260
# 3      5.6431      52.0  5.817352       558.0  2.547945
# 4      3.8462      52.0  6.281853       565.0  2.181467
# ...       ...       ...       ...         ...       ...
# 20635  1.5603      25.0  5.045455       845.0  2.560606
# 20636  2.5568      18.0  6.114035       356.0  3.122807
# 20637  1.7000      17.0  5.205543      1007.0  2.325635
# 20638  1.8672      18.0  5.329513       741.0  2.123209
# 20639  2.3886      16.0  5.254717      1387.0  2.616981
#
# [20640 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(xx,y,test_size=0.2,random_state=1)

# %%
x_train
# Out:
#        MedInc  HouseAge  AveRooms  Population  AveOccup
# 15961  3.1908      52.0  5.000000       879.0  3.117021
# 1771   3.6094      42.0  4.900990       971.0  3.204620
# 16414  2.6250      16.0  8.333333        20.0  3.333333
# 5056   1.5143      34.0  3.805981      3538.0  2.580598
# 8589   7.3356      38.0  5.894904       750.0  2.388535
# ...       ...       ...       ...         ...       ...
# 10955  1.7823      17.0  4.055046      1079.0  2.474771
# 17289  8.5608      42.0  6.788462       753.0  2.896154
# 5192   1.1326      42.0  4.890785       775.0  2.645051
# 12172  2.6322      10.0  4.991614      1323.0  2.773585
# 235    2.3036      35.0  4.620513      1009.0  2.587179
#
# [16512 rows x 5 columns]

# %%
from sklearn.linear_model import LinearRegression
model1=LinearRegression()

# %%
model1 = LinearRegression()
model1.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model1.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 0.6445452038751992

# %%
import pickle
pickle.dump(model,open("model.pkl",'wb')) #wb stands for write binary

# %%
model=pickle.load(open('model.pkl','rb'))

# %%
model
# Out:
# LinearRegression()
